# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

from hydxscomp.crosssection import CrossSection


station, elevation = np.loadtxt(r'data/xs.csv', delimiter=',', skiprows=1, unpack=True)
_ = plt.plot(station, elevation)

# %%
sect_stat = [75, 520, 1850, 2040]
roughness = [0.09, 0.06, 0.035, 0.06, 0.09]
xs = CrossSection(station, elevation, roughness, sect_stat)
_ = xs.plot(380)

# %%
xs.roughness([360, 380, 399])
# Out:
# array([0.03574856, 0.03901714, 0.04208709])
